# %% [markdown]
# # Example calculation of the biological component of DIC in the global oceans
#
# by Greg Pelletier, 16-Feb-2025
#
# The surface water DIC concentration of a given water mass is altered by air–sea gas exchange, the biological production/consumption of organic matter, and calcium carbonate (CaCO3) formation/dissolution (Burt et al, 2016). To isolate the biological component of DIC, a surface DIC concentration at atmospheric equilibrium is computed and subsequently removed from the observed DIC (DICobs).
#
# We use the following equation to represent DICbio:
#
# DICbio = DICobs – DICatm				(eqn 1)
#
#
# where
#
# - DICobs = observed DIC (OceanSODA-ETHZ)
# - DICatm = DIC at equilibrium with atmospheric pCO2 and observed TA
#
# We use the DIC reported in OceanSODA-ETHZ as the value of "DICobs" in each month at each grid
# cell from 1982-2022. Next, we calculate "DICatm" with PyCO2SYS using
# the atmospheric pCO2 from the SeaFlux data set, combined the observed
# TA from OceanSODA-ETHZ in each grid cell for each month from
# 1982-2022. Therefore, "DICatm" represents the hypothetical DIC that
# would be in equilibrium with the atmospheric pCO2. Finally, we
# calculated the 1982-2022 monthly values of "DICbio" using eqn 1 as
# DICbio = DICobs - DICatm
#
# The repeating annual cycle of DICbio can be represented as a sine function of the following form:
#
# y = mean + amplitude * sin(2π * (x - phase) / period)	(eqn 2)
#
# where
#
# - y = DICbio = DICobs – DICatm
# - x = time as decimal year fraction (1982-2022)
# - mean = mean from sine-regression
# - amplitude = amplitude from sine-regression
# - phase = phase shift from sine-regression
# - period = assumed equal to 1 cycle per year
#
# PyOAE incudes functions (dic_bio and sine_fit) to calculate DICbio using eqn 1, and to find the optimum parameters of the sine-regression model in eqn 2. We solve for the best-fit values of the parameters in eqn 2 at each grid cell including the mean,
# amplitude, and phase of the sine function at each location.
#
# In this example we use a netcdf file available in the PyOAE repository that contains the subset of data from OceanSODA-ETHZ and SeaFlux that we need to do the analysis. We use the
# 1982-2022 monthly time series of DICbio as the observed "y" values in
# eqn 2 to estimate the best-fit parameters of eqn 2 at each location.
#
# References:
# - Clargo et al 2015 (https://doi.org/10.1016/j.marchem.2015.08.010)
# - Burt et al 2016 (https://doi.org/10.1002/lno.10243):
#
# In the following code block we loop through all of the grid cells in the global oceans to do the analysis. This next code block takes about 45 minutes to calculate the monthly DICbio in each grid cell from 1982-2022, and solve for the best fit sine-regression model in each grid cell

# %%
# Note: time index 0:468 is the range of 1982-2020 data in pco2atm from SeaFlux v2021
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from PyOAE import dic_bio, sine_fit
# read the data into an xarray dataset
ds1 = xr.open_dataset("OceanSODA_ETHZ_for_PyOAE.nc", chunks={"lon":0})
ds2 = xr.open_dataset("SeaFlux_for_PyOAE.nc", chunks={"lon":0})
# Convert ds1 to dictionary of numpy arrays for computations
ds_dict = {var: ds1[var].values for var in ds1.data_vars}
# append yearfrac,lon,lat,time,pco2atm,fco2atm to ds_dict
ds_dict["yearfrac"] = ds1.yearfrac.values
ds_dict["lon"] = ds1.lon.values
ds_dict["lat"] = ds1.lat.values
ds_dict["time"] = ds1.time.values
ds_dict["pco2atm"] = ds2.pco2atm.values
ds_dict["fco2atm"] = ds2.fco2atm.values
# initialize new output arrays for ds_dict
ds_dict["dic_atm"] = np.full_like(ds_dict["talk"], np.nan)
ds_dict["dic_bio"] = np.full_like(ds_dict["talk"], np.nan)
ds_dict["dic_bio_fit"] = np.full_like(ds_dict["talk"], np.nan)
ds_dict["dic_bio_mean"] = np.full_like(ds_dict["lon"], np.nan)
ds_dict["dic_bio_amplitude"] = np.full_like(ds_dict["lon"], np.nan)
ds_dict["dic_bio_phase"] = np.full_like(ds_dict["lon"], np.nan)
ds_dict["dic_bio_rmse"] = np.full_like(ds_dict["lon"], np.nan)
ds_dict["dic_bio_adj_rsquared"] = np.full_like(ds_dict["lon"], np.nan)
ds_dict["dic_bio_pvalue"] = np.full_like(ds_dict["lon"], np.nan)
for i in range(ds_dict["talk"].shape[2]):
    print("dic_bio computed at lon %.1f degE" % (i+0.5))
    for j in range(ds_dict["talk"].shape[1]):
        kwargs = {
            'alkalinity': ds_dict["talk"][0:468,j,i],
            'dic': ds_dict["dic"][0:468,j,i],
            'pco2atm': ds_dict["pco2atm"][0:468,j,i],
            'total_silicate': ds_dict["sio3"][0:468,j,i],
            'total_phosphate': ds_dict["po4"][0:468,j,i],
            'temperature': ds_dict["temperature"][0:468,j,i],
            'salinity': ds_dict["salinity"][0:468,j,i],
            'total_pressure': 0,
            'opt_pH_scale': 1,  # pH scale (1= total scale)
            'opt_k_carbonic': 10,  # Choice of H2CO3 and HCO3- K1 and K2 (10= Lueker et al 2000)
            'opt_k_bisulfate': 1,  # Choice of HSO4- dissociation constant KSO4 (1= Dickson)
            'opt_total_borate': 1,  # Choice for boron:sal 
            'opt_k_fluoride': 1   # Choice for fluoride
            }
        # nnn = number of non-nan values for each input variable to dic_bio         
        nnn_talk = np.count_nonzero(~np.isnan(kwargs["alkalinity"]))  # number of non-nan
        nnn_dic = np.count_nonzero(~np.isnan(kwargs["dic"]))  # number of non-nan
        nnn_pco2atm = np.count_nonzero(~np.isnan(kwargs["pco2atm"]))  # number of non-nan
        nnn_sio3 = np.count_nonzero(~np.isnan(kwargs["total_silicate"]))  # number of non-nan
        nnn_po4 = np.count_nonzero(~np.isnan(kwargs["total_phosphate"]))  # number of non-nan
        nnn_temp = np.count_nonzero(~np.isnan(kwargs["temperature"]))  # number of non-nan
        nnn_sal = np.count_nonzero(~np.isnan(kwargs["salinity"]))  # number of non-nan
        if (nnn_talk==nnn_dic and nnn_talk==nnn_pco2atm and nnn_talk==nnn_sio3 and 
            nnn_talk==nnn_po4 and nnn_talk==nnn_temp and nnn_talk==nnn_sal and nnn_talk > 0):
            # solve for dic_bio = dic_obs - dic_atm
            result_1 = dic_bio(**kwargs)
            ds_dict["dic_atm"][0:468,j,i]= result_1["dic_atm"]
            ds_dict["dic_bio"][0:468,j,i] = result_1["dic_bio"]
            # solve for dic_bio vs time sine-regression mean, amplitude, phase, rmse, y_fit
            result_2 = sine_fit(ds_dict["yearfrac"][0:468],result_1["dic_bio"])  
            ds_dict["dic_bio_fit"][0:468,j,i]= result_2["y_fit"]
            ds_dict["dic_bio_mean"][j,i]= result_2["mean"]
            ds_dict["dic_bio_amplitude"][j,i]= result_2["amplitude"]
            ds_dict["dic_bio_phase"][j,i]= result_2["phase"]
            ds_dict["dic_bio_rmse"][j,i]= result_2["rmse"]
            ds_dict["dic_bio_adj_rsquared"][j,i]= result_2["adj_rsquared"]
            ds_dict["dic_bio_pvalue"][j,i]= result_2["pvalue"]
# Out:
# dic_bio computed at lon 0.5 degE
# dic_bio computed at lon 1.5 degE
# dic_bio computed at lon 2.5 degE
# dic_bio computed at lon 3.5 degE
# dic_bio computed at lon 4.5 degE
# dic_bio computed at lon 5.5 degE
# dic_bio computed at lon 6.5 degE
# dic_bio computed at lon 7.5 degE
# dic_bio computed at lon 8.5 degE
# dic_bio computed at lon 9.5 degE
# dic_bio computed at lon 10.5 degE
# dic_bio computed at lon 11.5 degE
# dic_bio computed at lon 12.5 degE
# dic_bio computed at lon 13.5 degE
# dic_bio computed at lon 14.5 degE
# dic_bio computed at lon 15.5 degE
# dic_bio computed at lon 16.5 degE
# dic_bio computed at lon 17.5 degE
# dic_bio computed at lon 18.5 degE
# dic_bio computed at lon 19.5 degE
# dic_bio computed at lon 20.5 degE
# dic_bio computed at lon 21.5 degE
# dic_bio computed at lon 22.5 degE
# dic_bio computed at lon 23.5 degE
# dic_bio computed at lon 24.5 degE
# dic_bio computed at lon 25.5 degE
# dic_bio computed at lon 26.5 degE
# dic_bio computed at lon 27.5 degE
# dic_bio computed at lon 28.5 degE
# dic_bio computed at lon 29.5 degE
# dic_bio computed at lon 30.5 degE
# dic_bio computed at lon 31.5 degE
# dic_bio computed at lon 32.5 degE
# dic_bio computed at lon 33.5 degE
# dic_bio computed at lon 34.5 degE
# dic_bio computed at lon 35.5 degE
# dic_bio computed at lon 36.5 degE
# dic_bio computed at lon 37.5 degE
# dic_bio computed at lon 38.5 degE
# dic_bio computed at lon 39.5 degE
# dic_bio computed at lon 40.5 degE
# dic_bio computed at lon 41.5 degE
# dic_bio computed at lon 42.5 degE
# dic_bio computed at lon 43.5 degE
# dic_bio computed at lon 44.5 degE
# dic_bio computed at lon 45.5 degE
# dic_bio computed at lon 46.5 degE
# dic_bio computed at lon 47.5 degE
# dic_bio computed at lon 48.5 degE
# dic_bio computed at lon 49.5 degE
# dic_bio computed at lon 50.5 degE
# dic_bio computed at lon 51.5 degE
# dic_bio computed at lon 52.5 degE
# dic_bio computed at lon 53.5 degE
# dic_bio computed at lon 54.5 degE
# dic_bio computed at lon 55.5 degE
# dic_bio computed at lon 56.5 degE
# dic_bio computed at lon 57.5 degE
# dic_bio computed at lon 58.5 degE
# dic_bio computed at lon 59.5 degE
# dic_bio computed at lon 60.5 degE
# dic_bio computed at lon 61.5 degE
# dic_bio computed at lon 62.5 degE
# dic_bio computed at lon 63.5 degE
# dic_bio computed at lon 64.5 degE
# dic_bio computed at lon 65.5 degE
# dic_bio computed at lon 66.5 degE
# dic_bio computed at lon 67.5 degE
# dic_bio computed at lon 68.5 degE
# dic_bio computed at lon 69.5 degE
# dic_bio computed at lon 70.5 degE
# dic_bio computed at lon 71.5 degE
# dic_bio computed at lon 72.5 degE
# dic_bio computed at lon 73.5 degE
# dic_bio computed at lon 74.5 degE
# dic_bio computed at lon 75.5 degE
# dic_bio computed at lon 76.5 degE
# dic_bio computed at lon 77.5 degE
# dic_bio computed at lon 78.5 degE
# dic_bio computed at lon 79.5 degE
# dic_bio computed at lon 80.5 degE
# dic_bio computed at lon 81.5 degE
# dic_bio computed at lon 82.5 degE
# dic_bio computed at lon 83.5 degE
# dic_bio computed at lon 84.5 degE
# dic_bio computed at lon 85.5 degE
# dic_bio computed at lon 86.5 degE
# dic_bio computed at lon 87.5 degE
# dic_bio computed at lon 88.5 degE
# dic_bio computed at lon 89.5 degE
# dic_bio computed at lon 90.5 degE
# dic_bio computed at lon 91.5 degE
# dic_bio computed at lon 92.5 degE
# dic_bio computed at lon 93.5 degE
# dic_bio computed at lon 94.5 degE
# dic_bio computed at lon 95.5 degE
# dic_bio computed at lon 96.5 degE
# dic_bio computed at lon 97.5 degE
# dic_bio computed at lon 98.5 degE
# dic_bio computed at lon 99.5 degE
# dic_bio computed at lon 100.5 degE
# dic_bio computed at lon 101.5 degE
# dic_bio computed at lon 102.5 degE
# dic_bio computed at lon 103.5 degE
# dic_bio computed at lon 104.5 degE
# dic_bio computed at lon 105.5 degE
# dic_bio computed at lon 106.5 degE
# dic_bio computed at lon 107.5 degE
# dic_bio computed at lon 108.5 degE
# dic_bio computed at lon 109.5 degE
# dic_bio computed at lon 110.5 degE
# dic_bio computed at lon 111.5 degE
# dic_bio computed at lon 112.5 degE
# dic_bio computed at lon 113.5 degE
# dic_bio computed at lon 114.5 degE
# dic_bio computed at lon 115.5 degE
# dic_bio computed at lon 116.5 degE
# dic_bio computed at lon 117.5 degE
# dic_bio computed at lon 118.5 degE
# dic_bio computed at lon 119.5 degE
# dic_bio computed at lon 120.5 degE
# dic_bio computed at lon 121.5 degE
# dic_bio computed at lon 122.5 degE
# dic_bio computed at lon 123.5 degE
# dic_bio computed at lon 124.5 degE
# dic_bio computed at lon 125.5 degE
# dic_bio computed at lon 126.5 degE
# dic_bio computed at lon 127.5 degE
# dic_bio computed at lon 128.5 degE
# dic_bio computed at lon 129.5 degE
# dic_bio computed at lon 130.5 degE
# dic_bio computed at lon 131.5 degE
# dic_bio computed at lon 132.5 degE
# dic_bio computed at lon 133.5 degE
# dic_bio computed at lon 134.5 degE
# dic_bio computed at lon 135.5 degE
# dic_bio computed at lon 136.5 degE
# dic_bio computed at lon 137.5 degE
# dic_bio computed at lon 138.5 degE
# dic_bio computed at lon 139.5 degE
# dic_bio computed at lon 140.5 degE
# dic_bio computed at lon 141.5 degE
# dic_bio computed at lon 142.5 degE
# dic_bio computed at lon 143.5 degE
# dic_bio computed at lon 144.5 degE
# dic_bio computed at lon 145.5 degE
# dic_bio computed at lon 146.5 degE
# dic_bio computed at lon 147.5 degE
# dic_bio computed at lon 148.5 degE
# dic_bio computed at lon 149.5 degE
# dic_bio computed at lon 150.5 degE
# dic_bio computed at lon 151.5 degE
# dic_bio computed at lon 152.5 degE
# dic_bio computed at lon 153.5 degE
# dic_bio computed at lon 154.5 degE
# dic_bio computed at lon 155.5 degE
# dic_bio computed at lon 156.5 degE
# dic_bio computed at lon 157.5 degE
# dic_bio computed at lon 158.5 degE
# dic_bio computed at lon 159.5 degE
# dic_bio computed at lon 160.5 degE
# dic_bio computed at lon 161.5 degE
# dic_bio computed at lon 162.5 degE
# dic_bio computed at lon 163.5 degE
# dic_bio computed at lon 164.5 degE
# dic_bio computed at lon 165.5 degE
# dic_bio computed at lon 166.5 degE
# dic_bio computed at lon 167.5 degE
# dic_bio computed at lon 168.5 degE
# dic_bio computed at lon 169.5 degE
# dic_bio computed at lon 170.5 degE
# dic_bio computed at lon 171.5 degE
# dic_bio computed at lon 172.5 degE
# dic_bio computed at lon 173.5 degE
# dic_bio computed at lon 174.5 degE
# dic_bio computed at lon 175.5 degE
# dic_bio computed at lon 176.5 degE
# dic_bio computed at lon 177.5 degE
# dic_bio computed at lon 178.5 degE
# dic_bio computed at lon 179.5 degE
# dic_bio computed at lon 180.5 degE
# dic_bio computed at lon 181.5 degE
# dic_bio computed at lon 182.5 degE
# dic_bio computed at lon 183.5 degE
# dic_bio computed at lon 184.5 degE
# dic_bio computed at lon 185.5 degE
# dic_bio computed at lon 186.5 degE
# dic_bio computed at lon 187.5 degE
# dic_bio computed at lon 188.5 degE
# dic_bio computed at lon 189.5 degE
# dic_bio computed at lon 190.5 degE
# dic_bio computed at lon 191.5 degE
# dic_bio computed at lon 192.5 degE
# dic_bio computed at lon 193.5 degE
# dic_bio computed at lon 194.5 degE
# dic_bio computed at lon 195.5 degE
# dic_bio computed at lon 196.5 degE
# dic_bio computed at lon 197.5 degE
# dic_bio computed at lon 198.5 degE
# dic_bio computed at lon 199.5 degE
# dic_bio computed at lon 200.5 degE
# dic_bio computed at lon 201.5 degE
# dic_bio computed at lon 202.5 degE
# dic_bio computed at lon 203.5 degE
# dic_bio computed at lon 204.5 degE
# dic_bio computed at lon 205.5 degE
# dic_bio computed at lon 206.5 degE
# dic_bio computed at lon 207.5 degE
# dic_bio computed at lon 208.5 degE
# dic_bio computed at lon 209.5 degE
# dic_bio computed at lon 210.5 degE
# dic_bio computed at lon 211.5 degE
# dic_bio computed at lon 212.5 degE
# dic_bio computed at lon 213.5 degE
# dic_bio computed at lon 214.5 degE
# dic_bio computed at lon 215.5 degE
# dic_bio computed at lon 216.5 degE
# dic_bio computed at lon 217.5 degE
# dic_bio computed at lon 218.5 degE
# dic_bio computed at lon 219.5 degE
# dic_bio computed at lon 220.5 degE
# dic_bio computed at lon 221.5 degE
# dic_bio computed at lon 222.5 degE
# dic_bio computed at lon 223.5 degE
# dic_bio computed at lon 224.5 degE
# dic_bio computed at lon 225.5 degE
# dic_bio computed at lon 226.5 degE
# dic_bio computed at lon 227.5 degE
# dic_bio computed at lon 228.5 degE
# dic_bio computed at lon 229.5 degE
# dic_bio computed at lon 230.5 degE
# dic_bio computed at lon 231.5 degE
# dic_bio computed at lon 232.5 degE
# dic_bio computed at lon 233.5 degE
# dic_bio computed at lon 234.5 degE
# dic_bio computed at lon 235.5 degE
# dic_bio computed at lon 236.5 degE
# dic_bio computed at lon 237.5 degE
# dic_bio computed at lon 238.5 degE
# dic_bio computed at lon 239.5 degE
# dic_bio computed at lon 240.5 degE
# dic_bio computed at lon 241.5 degE
# dic_bio computed at lon 242.5 degE
# dic_bio computed at lon 243.5 degE
# dic_bio computed at lon 244.5 degE
# dic_bio computed at lon 245.5 degE
# dic_bio computed at lon 246.5 degE
# dic_bio computed at lon 247.5 degE
# dic_bio computed at lon 248.5 degE
# dic_bio computed at lon 249.5 degE
# dic_bio computed at lon 250.5 degE
# dic_bio computed at lon 251.5 degE
# dic_bio computed at lon 252.5 degE
# dic_bio computed at lon 253.5 degE
# dic_bio computed at lon 254.5 degE
# dic_bio computed at lon 255.5 degE
# dic_bio computed at lon 256.5 degE
# dic_bio computed at lon 257.5 degE
# dic_bio computed at lon 258.5 degE
# dic_bio computed at lon 259.5 degE
# dic_bio computed at lon 260.5 degE
# dic_bio computed at lon 261.5 degE
# dic_bio computed at lon 262.5 degE
# dic_bio computed at lon 263.5 degE
# dic_bio computed at lon 264.5 degE
# dic_bio computed at lon 265.5 degE
# dic_bio computed at lon 266.5 degE
# dic_bio computed at lon 267.5 degE
# dic_bio computed at lon 268.5 degE
# dic_bio computed at lon 269.5 degE
# dic_bio computed at lon 270.5 degE
# dic_bio computed at lon 271.5 degE
# dic_bio computed at lon 272.5 degE
# dic_bio computed at lon 273.5 degE
# dic_bio computed at lon 274.5 degE
# dic_bio computed at lon 275.5 degE
# dic_bio computed at lon 276.5 degE
# dic_bio computed at lon 277.5 degE
# dic_bio computed at lon 278.5 degE
# dic_bio computed at lon 279.5 degE
# dic_bio computed at lon 280.5 degE
# dic_bio computed at lon 281.5 degE
# dic_bio computed at lon 282.5 degE
# dic_bio computed at lon 283.5 degE
# dic_bio computed at lon 284.5 degE
# dic_bio computed at lon 285.5 degE
# dic_bio computed at lon 286.5 degE
# dic_bio computed at lon 287.5 degE
# dic_bio computed at lon 288.5 degE
# dic_bio computed at lon 289.5 degE
# dic_bio computed at lon 290.5 degE
# dic_bio computed at lon 291.5 degE
# dic_bio computed at lon 292.5 degE
# dic_bio computed at lon 293.5 degE
# dic_bio computed at lon 294.5 degE
# dic_bio computed at lon 295.5 degE
# dic_bio computed at lon 296.5 degE
# dic_bio computed at lon 297.5 degE
# dic_bio computed at lon 298.5 degE
# dic_bio computed at lon 299.5 degE
# dic_bio computed at lon 300.5 degE
# dic_bio computed at lon 301.5 degE
# dic_bio computed at lon 302.5 degE
# dic_bio computed at lon 303.5 degE
# dic_bio computed at lon 304.5 degE
# dic_bio computed at lon 305.5 degE
# dic_bio computed at lon 306.5 degE
# dic_bio computed at lon 307.5 degE
# dic_bio computed at lon 308.5 degE
# dic_bio computed at lon 309.5 degE
# dic_bio computed at lon 310.5 degE
# dic_bio computed at lon 311.5 degE
# dic_bio computed at lon 312.5 degE
# dic_bio computed at lon 313.5 degE
# dic_bio computed at lon 314.5 degE
# dic_bio computed at lon 315.5 degE
# dic_bio computed at lon 316.5 degE
# dic_bio computed at lon 317.5 degE
# dic_bio computed at lon 318.5 degE
# dic_bio computed at lon 319.5 degE
# dic_bio computed at lon 320.5 degE
# dic_bio computed at lon 321.5 degE
# dic_bio computed at lon 322.5 degE
# dic_bio computed at lon 323.5 degE
# dic_bio computed at lon 324.5 degE
# dic_bio computed at lon 325.5 degE
# dic_bio computed at lon 326.5 degE
# dic_bio computed at lon 327.5 degE
# dic_bio computed at lon 328.5 degE
# dic_bio computed at lon 329.5 degE
# dic_bio computed at lon 330.5 degE
# dic_bio computed at lon 331.5 degE
# dic_bio computed at lon 332.5 degE
# dic_bio computed at lon 333.5 degE
# dic_bio computed at lon 334.5 degE
# dic_bio computed at lon 335.5 degE
# dic_bio computed at lon 336.5 degE
# dic_bio computed at lon 337.5 degE
# dic_bio computed at lon 338.5 degE
# dic_bio computed at lon 339.5 degE
# dic_bio computed at lon 340.5 degE
# dic_bio computed at lon 341.5 degE
# dic_bio computed at lon 342.5 degE
# dic_bio computed at lon 343.5 degE
# dic_bio computed at lon 344.5 degE
# dic_bio computed at lon 345.5 degE
# dic_bio computed at lon 346.5 degE
# dic_bio computed at lon 347.5 degE
# dic_bio computed at lon 348.5 degE
# dic_bio computed at lon 349.5 degE
# dic_bio computed at lon 350.5 degE
# dic_bio computed at lon 351.5 degE
# dic_bio computed at lon 352.5 degE
# dic_bio computed at lon 353.5 degE
# dic_bio computed at lon 354.5 degE
# dic_bio computed at lon 355.5 degE
# dic_bio computed at lon 356.5 degE
# dic_bio computed at lon 357.5 degE
# dic_bio computed at lon 358.5 degE
# dic_bio computed at lon 359.5 degE

# %% [markdown]
# Next we will make a map showing the results for the regression estimate of the mean DICbio

# %%
from matplotlib.colors import TwoSlopeNorm
# plot a map
plt.figure(figsize=(8, 5),dpi=150)  # Set the figure size (width, height)
# Define the zero point
vmin = np.nanpercentile(ds_dict['dic_bio_mean'],1)
vmax = np.nanpercentile(ds_dict['dic_bio_mean'],99)
vcenter = 0
# Create a normalization instance
norm = TwoSlopeNorm(vmin=vmin, vcenter=vcenter, vmax=vmax)
plt.imshow(np.flipud(ds_dict['dic_bio_mean']), cmap='seismic', interpolation='none', norm=norm)
plt.colorbar(orientation="horizontal", pad=0.03)  # Add a colorbar for reference
plt.title(r'Figure 5. Mean DICbio umol/kg')
plt.xticks([])
plt.yticks([])
plt.savefig('Fig5_map_of_DICbio_mean_using_pco2atm_as_pcco2.png', format='png', dpi=300)
plt.show()

# %% [markdown]
# Next we will make a map showing the results of the regression estimate of the amplitude of DICbio. Note that the amplitude represents half of the distance from the peak to the trough of each seasonal cycle. Therefore the amplitude is half of the annual range of DICbio

# %%
# plot a map
X = ds_dict['lon']
Y = ds_dict['lat']
Z = np.flipud(np.abs(ds_dict['dic_bio_amplitude']))
zmin = np.nanpercentile(Z,0.5)
zmax = np.nanpercentile(Z,99.5)
plt.figure(figsize=(8, 5),dpi=150)  # Set the figure size (width, height)
plt.imshow(Z, cmap='plasma', interpolation='none', vmin=zmin, vmax=zmax)
plt.colorbar(orientation="horizontal", pad=0.03)  # Add a colorbar for reference
plt.title(r'Figure 6. Amplitude of DICbio umol/kg')
plt.xticks([])
plt.yticks([])
plt.savefig('Fig6_map_of_DICbio_amplitude_using_pco2atm_as_pcco2.png', format='png', dpi=300)
plt.show()

# %% [markdown]
# Next we will make a map showing the p-values of the sine-regressions. Most of the grid cells have statistically signficant regressions (p<0.05)

# %%
# plot a map
X = ds_dict['lon']
Y = ds_dict['lat']
Z = np.flipud(np.abs(ds_dict['dic_bio_pvalue']))
plt.figure(figsize=(8, 5),dpi=150)  # Set the figure size (width, height)
# Define the zero point
vmin = 0
vmax = 0.2
vcenter = 0.05
# Create a normalization instance
norm = TwoSlopeNorm(vmin=vmin, vcenter=vcenter, vmax=vmax)
plt.imshow(Z, cmap='seismic', interpolation='none', norm=norm)
plt.colorbar(orientation="horizontal", pad=0.03)  # Add a colorbar for reference
plt.title(r'Figure 7. p-value of DICbio sine-regressions')
plt.xticks([])
plt.yticks([])
plt.savefig('Fig7_map_of_DICbio_pvalue_using_pco2atm_as_pcco2.png', format='png', dpi=300)
plt.show()

# %% [markdown]
# Finally, we will make a map showing the adjusted r^2 values for the regressions in each grid cell. Note that the r^2 values tend to be greater in areas that have the largest amplitudes. In other words, the regressions are best in areas where there is the greatest biogeochemical effect in DICbio

# %%
# plot a map
X = ds_dict['lon']
Y = ds_dict['lat']
Z = np.flipud(np.abs(ds_dict['dic_bio_adj_rsquared']))
plt.figure(figsize=(8, 5),dpi=150)  # Set the figure size (width, height)
# Define the zero point
vmin = 0
vmax = 1.0
vcenter = 0.5
# Create a normalization instance
norm = TwoSlopeNorm(vmin=vmin, vcenter=vcenter, vmax=vmax)
plt.imshow(Z, cmap='seismic_r', interpolation='none', norm=norm)
plt.colorbar(orientation="horizontal", pad=0.03)  # Add a colorbar for reference
plt.title(r'Figure 8. Adjusted R-squared of DICbio sine-regressions')
plt.xticks([])
plt.yticks([])
plt.savefig('Fig8_map_of_DICbio_rsquared_using_pco2atm_as_pcco2.png', format='png', dpi=300)
plt.show()

# %%
# Columbia River location i,j coordinates
i=249
j=113

# style.use('ggplot')
fig, ax = plt.subplot_mosaic(
    '''
    A
    B
    ''',
    figsize = (9, 9), dpi=150
    # constrained_layout = True
)

# Plot at ['A']
ax['A'].plot(ds_dict["yearfrac"], ds_dict["dic"][:,j,i], label='DICobs (OceanSODA-ETHZ)', linestyle='-', marker='')
ax['A'].plot(ds_dict["yearfrac"], ds_dict["dic_atm"][:,j,i], label='DICatm (equilibrium with atmospheric pCO2)', linestyle='-')
# ax['A'].set_xlabel('year')
ax['A'].set_ylabel('DIC (umol/kg)')
ax['A'].legend(loc='upper left')
# ax['A'].grid(True)
ax['A'].set_title('a. DIC observed (DICobs), and at equilibrium with atmospheric pCO2 (DICatm)')
# ax['A'].set_xlim(2010, 2021)
ax['A'].set_xlim(1982, 2021)
ax['A'].set_ylim(1875, 2075)
# ax['A'].text(1983, 36.5, 'Mean: '+f"{A_fit:.1f}"+', Amplitude: '+f"{B_fit:.1f}"+', RMSE: '+f"{rmse:.1f}"+' umol/kg',
#         fontsize=10, color='black', ha='left', va='center')
# ax['A'].axhline(y=0, color='k', linestyle=':')

# Plot at ['B']
ax['B'].plot(ds_dict["yearfrac"], ds_dict["dic_bio"][:,j,i], label='DICbio = DICobs - DICatm', color='black', linestyle='-', marker='')
ax['B'].plot(ds_dict["yearfrac"], ds_dict["dic_bio_fit"][:,j,i], label='Regression', color='red', linestyle='--')
# ax['A'].set_xlabel('year')
ax['B'].set_ylabel('DICbio (umol/kg)')
ax['B'].legend(loc='upper left')
# ax['B'].grid(True)
ax['B'].set_title('b. DICbio = DICobs - DICatm')
# ax['B'].set_xlim(2010, 2021)
ax['B'].set_xlim(1982, 2021)
ax['B'].set_ylim(-20, 40)
# ax['B'].text(1983, -10, 'Mean: '+f"{A_fit:.1f}"+', Amplitude: '+f"{B_fit:.1f}"+', RMSE: '+f"{rmse:.1f}"+' umol/kg',
#         fontsize=10, color='black', ha='left', va='center')
ax['B'].text(1983, -17.5, 'Mean: '+f"{ds_dict["dic_bio_mean"][j,i]:.1f}"+', Amplitude: '+f"{ds_dict["dic_bio_amplitude"][j,i]:.1f}"+', RMSE: '+f"{ds_dict["dic_bio_rmse"][j,i]:.1f}"+' umol/kg',
        fontsize=10, color='black', ha='left', va='center')
ax['B'].axhline(y=0, color='k', linestyle=':')

fig.savefig('Fig9_DICobs_DICatm_DICbio_at_ColumbiaRiver_1982_2020_pco2atm_as_pco2.png', format='png');

# %%
# San Francisco
i=243
j=118

# style.use('ggplot')
fig, ax = plt.subplot_mosaic(
    '''
    A
    B
    ''',
    figsize = (9, 9), dpi=150
    # constrained_layout = True
)

# Plot at ['A']
ax['A'].plot(ds_dict["yearfrac"], ds_dict["dic"][:,j,i], label='DICobs (OceanSODA-ETHZ)', linestyle='-', marker='')
ax['A'].plot(ds_dict["yearfrac"], ds_dict["dic_atm"][:,j,i], label='DICatm (equilibrium with atmospheric pCO2)', linestyle='-')
# ax['A'].set_xlabel('year')
ax['A'].set_ylabel('DIC (umol/kg)')
ax['A'].legend(loc='upper left')
# ax['A'].grid(True)
ax['A'].set_title('a. DIC observed (DICobs), and at equilibrium with atmospheric pCO2 (DICatm)')
# ax['A'].set_xlim(2010, 2021)
ax['A'].set_xlim(1982, 2021)
ax['A'].set_ylim(1875, 2075)
# ax['A'].text(1983, 36.5, 'Mean: '+f"{A_fit:.1f}"+', Amplitude: '+f"{B_fit:.1f}"+', RMSE: '+f"{rmse:.1f}"+' umol/kg',
#         fontsize=10, color='black', ha='left', va='center')
# ax['A'].axhline(y=0, color='k', linestyle=':')

# Plot at ['B']
ax['B'].plot(ds_dict["yearfrac"], ds_dict["dic_bio"][:,j,i], label='DICbio = DICobs - DICatm', color='black', linestyle='-', marker='')
ax['B'].plot(ds_dict["yearfrac"], ds_dict["dic_bio_fit"][:,j,i], label='Regression', color='red', linestyle='--')
# ax['A'].set_xlabel('year')
ax['B'].set_ylabel('DICbio (umol/kg)')
ax['B'].legend(loc='upper left')
# ax['B'].grid(True)
ax['B'].set_title('b. DICbio = DICobs - DICatm')
# ax['B'].set_xlim(2010, 2021)
ax['B'].set_xlim(1982, 2021)
# ax['B'].text(1983, -10, 'Mean: '+f"{A_fit:.1f}"+', Amplitude: '+f"{B_fit:.1f}"+', RMSE: '+f"{rmse:.1f}"+' umol/kg',
#         fontsize=10, color='black', ha='left', va='center')
ax['B'].text(1983, -17.5, 'Mean: '+f"{ds_dict["dic_bio_mean"][j,i]:.1f}"+', Amplitude: '+f"{ds_dict["dic_bio_amplitude"][j,i]:.1f}"+', RMSE: '+f"{ds_dict["dic_bio_rmse"][j,i]:.1f}"+' umol/kg',
        fontsize=10, color='black', ha='left', va='center')
ax['B'].set_ylim(-20, 40)
ax['B'].axhline(y=0, color='k', linestyle=':')

fig.savefig('Fig10_DICobs_DICatm_DICbio_at_SanFrancisco_1982_2020_pco2atm_as_pco2.png', format='png');

# %%
# Huntington
i=241
j=123

# style.use('ggplot')
fig, ax = plt.subplot_mosaic(
    '''
    A
    B
    ''',
    figsize = (9, 9), dpi=150
    # constrained_layout = True
)

# Plot at ['A']
ax['A'].plot(ds_dict["yearfrac"], ds_dict["dic"][:,j,i], label='DICobs (OceanSODA-ETHZ)', linestyle='-', marker='')
ax['A'].plot(ds_dict["yearfrac"], ds_dict["dic_atm"][:,j,i], label='DICatm (equilibrium with atmospheric pCO2)', linestyle='-')
# ax['A'].set_xlabel('year')
ax['A'].set_ylabel('DIC (umol/kg)')
ax['A'].legend(loc='upper left')
# ax['A'].grid(True)
ax['A'].set_title('a. DIC observed (DICobs), and at equilibrium with atmospheric pCO2 (DICatm)')
# ax['A'].set_xlim(2010, 2021)
ax['A'].set_xlim(1982, 2021)
ax['A'].set_ylim(1875, 2075)
# ax['A'].text(1983, 36.5, 'Mean: '+f"{A_fit:.1f}"+', Amplitude: '+f"{B_fit:.1f}"+', RMSE: '+f"{rmse:.1f}"+' umol/kg',
#         fontsize=10, color='black', ha='left', va='center')
# ax['A'].axhline(y=0, color='k', linestyle=':')

# Plot at ['B']
ax['B'].plot(ds_dict["yearfrac"], ds_dict["dic_bio"][:,j,i], label='DICbio = DICobs - DICatm', color='black', linestyle='-', marker='')
ax['B'].plot(ds_dict["yearfrac"], ds_dict["dic_bio_fit"][:,j,i], label='Regression', color='red', linestyle='--')
# ax['A'].set_xlabel('year')
ax['B'].set_ylabel('DICbio (umol/kg)')
ax['B'].legend(loc='upper left')
# ax['B'].grid(True)
ax['B'].set_title('b. DICbio = DICobs - DICatm')
# ax['B'].set_xlim(2010, 2021)
ax['B'].set_xlim(1982, 2021)
# ax['B'].text(1983, -10, 'Mean: '+f"{A_fit:.1f}"+', Amplitude: '+f"{B_fit:.1f}"+', RMSE: '+f"{rmse:.1f}"+' umol/kg',
#         fontsize=10, color='black', ha='left', va='center')
ax['B'].text(1983, -17.5, 'Mean: '+f"{ds_dict["dic_bio_mean"][j,i]:.1f}"+', Amplitude: '+f"{ds_dict["dic_bio_amplitude"][j,i]:.1f}"+', RMSE: '+f"{ds_dict["dic_bio_rmse"][j,i]:.1f}"+' umol/kg',
        fontsize=10, color='black', ha='left', va='center')
ax['B'].set_ylim(-20, 40)
ax['B'].axhline(y=0, color='k', linestyle=':')

fig.savefig('Fig11_DICobs_DICatm_DICbio_at_Huntington_1982_2020_pco2atm_as_pco2.png', format='png');

# %% [markdown]
# # Save ds_dict as mat file

# %%
import scipy.io
scipy.io.savemat('OceanSODA_ETHZ_v2023_for_PyOAE_with_DICbio_using_pco2atm_as_pcco2.mat', ds_dict)
